# %% [markdown]
# # E-waste Classification with CNN
# ## Precious metals lost with e-waste
#
# As we're in a technological era, we're producing electronic devices more than ever. While consuming them, we're eager to hurl them away as soon as they're demolished. Although it's elementary to throw away the olds and produce a new device, we're losing our raw materials sources. According to the statistical records, each year we're losing tens of thousands of raw materials like copper, gold, alimnuim, etc.
#
# In the near future, we will not only face with lack of them, but deficiency of clean air and water. Because every unprocessed E-wastes is causing chemical pollution for the water resources and releasing toxic gasses to the atmosphere.
#
#
#
# The European Directive on Waste Electrical and Electronic Equipment divides waste into ten categories:
#
# **1) Large household appliances (refrigerators/freezers, washing machines, dishwashers)**
#
# **2) Small household appliances (toasters, coffee makers, irons, hairdryers)**
#
# **3) Information technology (IT) and telecommunications equipment (personal computers, telephones, mobile phones, laptops, printers, scanners, photocopiers)**
#
# **4) Consumer equipment (televisions, stereo equipment, electric toothbrushes)**
#
# **5) Lighting equipment (fluorescent lamps)**
#
# **6) Electrical and electronic tools (handheld drills, saws, screwdrivers)**
#
# **7) Toys, leisure and sports equipment**
#
# **8) Medical equipment systems (with the exception of all implanted and infected products)**
#
# **9) Monitoring and control instruments**
#
# **10) Automatic dispensers**
#
#
# In this notebook, we will be dealing just the third categories. Our aim to classify the e-wastes and give some information including their contents. If you want to contribute to the project, please get in touch.

# %% [markdown]
# ## Libraries

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread
import glob

# %%
my_data_dir = 'data/'

# %%
train_path = f'{my_data_dir}train'
test_path = f'{my_data_dir}test'

# %%
print(f"Train shape: {len(os.listdir(train_path))}")
print(f"Test shape: {len(os.listdir(test_path))}")
# Out:
# Train shape: 7
# Test shape: 7

# %% [markdown]
# ### Keyboard

# %%
os.listdir(f'{train_path}/keyboard')[0]
path1 = f'{train_path}/keyboard/keyboard12.jpeg'

# %%
keyboard_img = imread(path1)
plt.imshow(keyboard_img)

# %%
print(keyboard_img.max())
print(keyboard_img.min())
print(keyboard_img.shape)
# Out:
# 244
# 0
# (864, 1152, 3)

# %%
imread(path1)
# Out:
# array([[[219, 206, 190],
#         [219, 206, 190],
#         [219, 206, 190],
#         ...,
#         [ 37,  33,  32],
#         [ 37,  33,  32],
#         [ 37,  33,  32]],
#
#        [[219, 206, 190],
#         [219, 206, 190],
#         [219, 206, 190],
#         ...,
#         [ 36,  32,  31],
#         [ 37,  33,  32],
#         [ 37,  33,  32]],
#
#        [[219, 206, 190],
#         [219, 206, 190],
#         [219, 206, 190],
#         ...,
#         [ 36,  32,  31],
#         [ 36,  32,  31],
#         [ 37,  33,  32]],
#
#        ...,
#
#        [[228, 219, 202],
#         [228, 219, 202],
#         [228, 219, 202],
#         ...,
#         [217, 210, 182],
#         [217, 210, 182],
#         [217, 210, 182]],
#
#        [[228, 219, 202],
#         [228, 219, 202],
#         [228, 219, 202],
#         ...,
#         [217, 210, 182],
#         [217, 210, 182],
#         [217, 210, 182]],
#
#        [[228, 219, 202],
#         [228, 219, 202],
#         [228, 219, 202],
# ...

# %% [markdown]
# ### Mouse

# %%
os.listdir(f'{train_path}/mouse')[0]
path2 = f'{train_path}/mouse/mouse65.jpg'

# %%
mouse_img = imread(path2)
plt.imshow(mouse_img)

# %%
print(mouse_img.max())
print(mouse_img.min())
print(mouse_img.shape)
# Out:
# 255
# 0
# (1280, 720, 3)

# %%
imread(path2)
# Out:
# array([[[177, 173, 162],
#         [177, 173, 162],
#         [174, 172, 160],
#         ...,
#         [232, 231, 211],
#         [232, 231, 211],
#         [232, 231, 211]],
#
#        [[177, 173, 162],
#         [178, 174, 163],
#         [176, 174, 162],
#         ...,
#         [232, 231, 211],
#         [232, 231, 211],
#         [232, 231, 211]],
#
#        [[175, 171, 160],
#         [177, 173, 162],
#         [176, 174, 162],
#         ...,
#         [232, 231, 211],
#         [232, 231, 211],
#         [232, 231, 211]],
#
#        ...,
#
#        [[208, 202, 186],
#         [208, 202, 186],
#         [208, 202, 186],
#         ...,
#         [220, 213, 184],
#         [246, 238, 215],
#         [240, 233, 214]],
#
#        [[208, 202, 186],
#         [208, 202, 186],
#         [208, 202, 186],
#         ...,
#         [227, 221, 189],
#         [244, 236, 213],
#         [239, 230, 213]],
#
#        [[208, 202, 186],
#         [208, 202, 186],
#         [209, 203, 187],
# ...

# %% [markdown]
# ### Laptop

# %%
os.listdir(f'{train_path}/laptop')[0]
path3 = f'{train_path}/laptop/laptop202.jpg'

# %%
laptop_img = imread(path3)
plt.imshow(laptop_img)

# %%
print(laptop_img.max())
print(laptop_img.min())
print(laptop_img.shape)
# Out:
# 252
# 0
# (2340, 4160, 3)

# %%
imread(path3)
# Out:
# array([[[19, 23, 26],
#         [19, 23, 26],
#         [18, 22, 25],
#         ...,
#         [22, 23, 27],
#         [18, 19, 23],
#         [ 9, 10, 14]],
#
#        [[15, 19, 22],
#         [15, 19, 22],
#         [15, 19, 22],
#         ...,
#         [18, 19, 23],
#         [15, 16, 20],
#         [14, 15, 19]],
#
#        [[17, 21, 24],
#         [14, 18, 21],
#         [13, 17, 20],
#         ...,
#         [ 8,  9, 13],
#         [12, 13, 17],
#         [15, 16, 20]],
#
#        ...,
#
#        [[81, 79, 80],
#         [81, 79, 80],
#         [79, 77, 78],
#         ...,
#         [68, 71, 64],
#         [64, 67, 60],
#         [67, 70, 63]],
#
#        [[86, 84, 85],
#         [85, 83, 84],
#         [82, 80, 81],
#         ...,
#         [63, 66, 59],
#         [60, 63, 56],
#         [62, 65, 58]],
#
#        [[85, 83, 84],
#         [86, 84, 85],
#         [86, 84, 85],
#         ...,
#         [64, 67, 60],
#         [64, 67, 60],
#         [64, 67, 60]]], dtype=uint8)

# %% [markdown]
# ### Monitor

# %%
os.listdir(f'{train_path}/monitor')[0]
path4 = f'{train_path}/monitor/monitor68.jpeg'

# %%
monitor_img = imread(path4)
plt.imshow(monitor_img)

# %%
print(monitor_img.max())
print(monitor_img.min())
print(monitor_img.shape)
# Out:
# 255
# 0
# (864, 1152, 3)

# %%
imread(path4)
# Out:
# array([[[ 24,  20,  21],
#         [ 24,  20,  21],
#         [ 24,  20,  21],
#         ...,
#         [ 34,  28,  28],
#         [ 34,  28,  28],
#         [ 34,  28,  28]],
#
#        [[ 22,  18,  19],
#         [ 22,  18,  19],
#         [ 22,  18,  19],
#         ...,
#         [ 34,  28,  28],
#         [ 34,  28,  28],
#         [ 34,  28,  28]],
#
#        [[ 20,  16,  17],
#         [ 20,  16,  17],
#         [ 20,  16,  17],
#         ...,
#         [ 34,  28,  28],
#         [ 34,  28,  28],
#         [ 34,  28,  28]],
#
#        ...,
#
#        [[ 53,  24,  16],
#         [ 53,  24,  16],
#         [ 53,  24,  16],
#         ...,
#         [121,  70,  51],
#         [120,  69,  50],
#         [120,  69,  50]],
#
#        [[ 53,  24,  16],
#         [ 53,  24,  16],
#         [ 53,  24,  16],
#         ...,
#         [117,  66,  47],
#         [117,  66,  47],
#         [116,  65,  46]],
#
#        [[ 53,  24,  16],
#         [ 53,  24,  16],
#         [ 53,  24,  16],
# ...

# %% [markdown]
# ### Mobile

# %%
os.listdir(f'{train_path}/mobile')[0]
path5 = f'{train_path}/mobile/mobile110.jpg'

# %%
mobile_img = imread(path5)
plt.imshow(mobile_img)

# %%
print(mobile_img.max())
print(mobile_img.min())
print(mobile_img.shape)
# Out:
# 255
# 3
# (6000, 8000, 3)

# %%
imread(path5)
# Out:
# array([[[222, 221, 216],
#         [225, 224, 219],
#         [227, 226, 221],
#         ...,
#         [200, 202, 178],
#         [197, 199, 175],
#         [197, 199, 175]],
#
#        [[224, 223, 218],
#         [226, 225, 220],
#         [227, 226, 221],
#         ...,
#         [201, 203, 181],
#         [197, 199, 175],
#         [198, 200, 176]],
#
#        [[226, 225, 220],
#         [226, 225, 220],
#         [227, 226, 221],
#         ...,
#         [202, 204, 182],
#         [197, 199, 177],
#         [197, 199, 177]],
#
#        ...,
#
#        [[203, 172, 152],
#         [204, 173, 153],
#         [204, 173, 153],
#         ...,
#         [107,  93, 116],
#         [106,  92, 115],
#         [107,  93, 116]],
#
#        [[201, 170, 152],
#         [202, 171, 153],
#         [203, 172, 152],
#         ...,
#         [111, 103, 126],
#         [111, 103, 127],
#         [111, 102, 129]],
#
#        [[201, 170, 152],
#         [202, 171, 153],
#         [203, 172, 154],
# ...

# %% [markdown]
# ### Mix

# %%
os.listdir(f'{train_path}/mix')[0]
path6 = f'{train_path}/mix/mix76.jpg'

# %%
mix_img = imread(path6)
plt.imshow(mix_img)

# %%
print(mix_img.max())
print(mix_img.min())
print(mix_img.shape)
# Out:
# 255
# 0
# (4608, 3456, 3)

# %%
imread(path6)
# Out:
# array([[[100,  65,  46],
#         [ 94,  58,  42],
#         [ 91,  55,  41],
#         ...,
#         [213, 163, 140],
#         [216, 166, 143],
#         [219, 169, 146]],
#
#        [[ 94,  59,  40],
#         [ 91,  55,  39],
#         [ 92,  56,  42],
#         ...,
#         [213, 163, 140],
#         [217, 167, 144],
#         [217, 167, 144]],
#
#        [[ 96,  60,  44],
#         [ 86,  50,  34],
#         [ 77,  43,  31],
#         ...,
#         [214, 164, 141],
#         [217, 167, 144],
#         [217, 167, 144]],
#
#        ...,
#
#        [[218, 182, 156],
#         [216, 180, 154],
#         [216, 180, 154],
#         ...,
#         [211, 166, 137],
#         [212, 167, 138],
#         [212, 167, 138]],
#
#        [[217, 181, 155],
#         [215, 179, 153],
#         [215, 179, 153],
#         ...,
#         [210, 165, 136],
#         [211, 165, 139],
#         [212, 166, 140]],
#
#        [[215, 179, 153],
#         [213, 177, 151],
#         [213, 177, 151],
# ...

# %% [markdown]
# ### Preparing the data for the model

# %%
image_shape = (256,256,3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=20, # rotate the image 20 degrees
                               width_shift_range=0.10, # Shift the pic width by a max of 5%
                               height_shift_range=0.10, # Shift the pic height by a max of 5%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.1, # Shear means cutting away part of the image (max 10%)
                               zoom_range=0.1, # Zoom in by 10% max
                               horizontal_flip=True, # Allo horizontal flipping
                               fill_mode='nearest' # Fill in missing pixels with the nearest filled value
                              )

# %%
plt.imshow(image_gen.random_transform(keyboard_img))

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 175 images belonging to 6 classes.

# %% [markdown]
# ### Creating the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization

# %%
model = Sequential()

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
          
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())


model.add(Dense(128, activation='relu'))


model.add(Dense(6, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 128)     73856
#
#  conv2d_2 (Conv2D)           (None, 123, 123, 128)     147584
#
#  conv2d_3 (Conv2D)           (None, 121, 121, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 60, 60, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 58, 58, 64)        73792
#
#  max_pooling2d_2 (MaxPooling  (None, 29, 29, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 53824)             0
#
#  dense (Dense)               (None, 128)               6889600
#
#  dense_1 (Dense)             (None, 6)                 774
#
# ...
# Total params: 7,334,982
# Trainable params: 7,334,982
# Non-trainable params: 0
# ...

# %% [markdown]
# ### Early stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=10)
batch_size = 32

# %%
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=image_shape[:2],
                                                color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='binary', shuffle=True, seed = 42)
# Out:
# Found 450 images belonging to 6 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=image_shape[:2],
                                                color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='binary', shuffle=True, seed = 42)
# Out:
# Found 175 images belonging to 6 classes.

# %%
train_image_gen.class_indices
# Out:
# {'keyboard': 0, 'laptop': 1, 'mix': 2, 'mobile': 3, 'monitor': 4, 'mouse': 5}

# %%
test_image_gen.class_indices
# Out:
# {'keyboard': 0, 'laptop': 1, 'mix': 2, 'mobile': 3, 'monitor': 4, 'mouse': 5}

# %% [markdown]
# ### Model Training

# %%
STEP_SIZE_TRAIN=train_image_gen.n//train_image_gen.batch_size
STEP_SIZE_TEST=test_image_gen.n//test_image_gen.batch_size

# %%
STEP_SIZE_TRAIN, STEP_SIZE_TEST
# Out:
# (14, 5)

# %%
results = model.fit(train_image_gen,
                    epochs=20,
                    validation_data=test_image_gen,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_steps=STEP_SIZE_TEST,
                    callbacks=[early_stop])
# Out:
# Epoch 1/20
# 14/14 [==============================] - 163s 11s/step - loss: 1.8983 - accuracy: 0.2823 - val_loss: 1.6926 - val_accuracy: 0.3187
# Epoch 2/20
# 14/14 [==============================] - 141s 10s/step - loss: 1.6647 - accuracy: 0.3469 - val_loss: 1.6448 - val_accuracy: 0.3438
# Epoch 3/20
# 14/14 [==============================] - 128s 9s/step - loss: 1.6278 - accuracy: 0.3589 - val_loss: 1.6473 - val_accuracy: 0.3500
# Epoch 4/20
# 14/14 [==============================] - 129s 9s/step - loss: 1.6064 - accuracy: 0.3565 - val_loss: 1.6603 - val_accuracy: 0.3500
# Epoch 5/20
# 14/14 [==============================] - 129s 9s/step - loss: 1.5910 - accuracy: 0.3493 - val_loss: 1.6102 - val_accuracy: 0.3562
# Epoch 6/20
# 14/14 [==============================] - 129s 9s/step - loss: 1.5628 - accuracy: 0.3565 - val_loss: 1.6648 - val_accuracy: 0.3500
# Epoch 7/20
# ...

# %%
summary = pd.DataFrame(model.history.history)
summary
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.898299  0.282297  1.692580       0.31875
# 1   1.664713  0.346890  1.644825       0.34375
# 2   1.627756  0.358852  1.647282       0.35000
# 3   1.606385  0.356459  1.660345       0.35000
# 4   1.590963  0.349282  1.610181       0.35625
# 5   1.562783  0.356459  1.664786       0.35000
# 6   1.544585  0.385167  1.679307       0.34375
# 7   1.514574  0.356459  1.538457       0.40625
# 8   1.477044  0.406250  1.591731       0.40000
# 9   1.402967  0.404306  1.690788       0.39375
# 10  1.370996  0.454545  1.536803       0.42500
# 11  1.373099  0.456938  1.538172       0.36875
# 12  1.337029  0.473684  1.651052       0.40000
# 13  1.296330  0.466507  1.517279       0.42500
# 14  1.294939  0.483254  1.463503       0.43750
# 15  1.212446  0.509569  1.557151       0.42500
# 16  1.237625  0.521531  1.512916       0.40000
# 17  1.290607  0.485646  1.471313       0.48125
# 18  1.300322  0.483254  1.654134       0.46250
# ...

# %%
plt.figure(figsize=(10,6))
plt.plot(summary.loss, label="loss")
plt.plot(summary.val_loss, label="val_loss")
plt.legend(loc="upper right")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(summary.accuracy, label="accuracy")
plt.plot(summary.val_accuracy, label="val_accuracy")
plt.legend(loc="upper left")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.show()

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
model.evaluate(test_image_gen,
steps=STEP_SIZE_TEST)
# Out:
# 5/5 [==============================] - 18s 4s/step - loss: 1.5550 - accuracy: 0.4875
# [1.5550072193145752, 0.48750001192092896]

# %%
from tensorflow.keras.preprocessing import image

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=(130,130),
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical', shuffle=False, seed=42)
# Out:
# Found 175 images belonging to 6 classes.

# %% [markdown]
# ### Predictions

# %%
my_image = image.load_img("1.jpg", target_size=image_shape)

# %%
my_image = image.img_to_array(my_image)

# %%
type(my_image)
# Out:
# numpy.ndarray

# %%
my_image.shape
# Out:
# (256, 256, 3)

# %%
my_image = np.expand_dims(my_image, axis=0)

# %%
my_image.shape
# Out:
# (1, 256, 256, 3)

# %% [markdown]
# ### Prediction 1
# First prediction was correct. The model worked well.

# %%
model.predict(my_image)
# Out:
# array([[1.0000000e+00, 3.6217010e-33, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 3.1547403e-31]], dtype=float32)

# %%
my_image2 = image.load_img("2.jpeg", target_size=image_shape)

# %%
my_image2 = image.img_to_array(my_image2)

# %%
type(my_image2)
# Out:
# numpy.ndarray

# %%
my_image2= np.expand_dims(my_image2, axis=0)

# %%
my_image2.shape
# Out:
# (1, 256, 256, 3)

# %% [markdown]
# ### Prediction 2
# The second prediction was incorrect. The model couldn't predict this one.

# %%
model.predict(my_image2)
# Out:
# array([[0., 1., 0., 0., 0., 0.]], dtype=float32)

# %%
my_image3 = image.load_img("3.jpg", target_size=image_shape)

# %%
my_image3 = image.img_to_array(my_image3)

# %%
my_image3= np.expand_dims(my_image3, axis=0)

# %%
my_image3.shape
# Out:
# (1, 256, 256, 3)

# %% [markdown]
# ### Prediction 3
# The third prediction was correct. The model worked well.

# %%
np.argmax(model.predict(my_image3))
# Out:
# array([[0.0000000e+00, 9.9999988e-01, 1.0374821e-07, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00]], dtype=float32)

# %%
train_image_gen.class_indices
# Out:
# {'keyboard': 0, 'laptop': 1, 'mix': 2, 'mobile': 3, 'monitor': 4, 'mouse': 5}

# %%
test_image_gen.class_indices
# Out:
# {'keyboard': 0, 'laptop': 1, 'mix': 2, 'mobile': 3, 'monitor': 4, 'mouse': 5}

# %% [markdown]
# ## Conclusion
#
# In this notebook, we created an algorithm that identifies e-waste products in 6 categories. Although we have a well-structured algorithm, we could not obtain good results in accuracy scores due to insufficient data. But these results do not change the fact that this algorithm is the basic structure of the project.
#
# Even if the accuracy score was 0.58, the predictions were relatively better. For additionaly, we can use Image Augmentor for more data.
#
# For raise the awareness of e-waste, we could add information about contents of each products.

# %% [markdown]
# ## References
#
# - Dataset coming from: https://www.kaggle.com/datasets/kaustubh2402/ewaste-dataset
#
#
#
# - https://vincivilworld.com/2021/06/15/e-waste-classification-recycling-benefits/
#
# - https://dtsc.ca.gov/electronic-hazardous-waste/
#
# - https://www.paulsrubbish.com.au/7-types-e-waste/
#
# - https://www.abc.net.au/news/2013-06-13/researchers-worried-precious-metals-lost-in-e-waste-recycling/4750774?utm_campaign=abc_news_web&utm_content=link&utm_medium=content_shared&utm_source=abc_news_web
#
# - https://www.theguardian.com/environment/2020/jul/02/10bn-precious-metals-dumped-each-year-electronic-waste-un-toxic-e-waste-polluting
